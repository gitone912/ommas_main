# %%
import pandas as pd

# %%
path = 'sqm/bokaro.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     State  IMS_Year_Category       Location  \
# 0   Block                  1  Chandankiyari
# 1   Block                  1  Chandankiyari
# 2   Block                  2           Chas
# 3   Block                  2           Chas
# 4   Block                  3          Gomia
# 5   Block                  3          Gomia
# 6   Block                  4        Jaridhi
# 7   Block                  4        Jaridhi
# 8   Block                  5         Kasmar
# 9   Block                  5         Kasmar
# 10  Block                  6        Nawadih
# 11  Block                  6        Nawadih
# 12  Block                  7       Petarwar
# 13  Block                  7       Petarwar
#
#                                           Description  \
# 0           Unsatisfactory works grading during  2...
# 1           Unsatisfactory works grading during  2...
# 2           Unsatisfactory works grading during  2...
# 3           Unsatisfactory works grading during  2...
# ...

# %%
df = df.drop(['State'], axis=1)

# %%
df.to_csv(path, index=False)
