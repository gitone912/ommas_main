# %%
import pandas as pd 
import numpy as np

# %%
path = 'sqm_monitors_jh.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#     Textbox38        Textbox51      Textbox55 Textbox180 Textbox175 Textbox6  \
# 0     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 2     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 3     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 4     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# ..        ...              ...            ...        ...        ...      ...
# 200   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 201   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 202   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 203   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 204   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
#
# ...

# %%
print(df)
# Out:
#     Textbox38        Textbox51      Textbox55 Textbox180 Textbox175 Textbox6  \
# 0     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 2     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 3     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 4     Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# ..        ...              ...            ...        ...        ...      ...
# 200   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 201   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 202   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 203   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 204   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
#
# ...

# %%
df = df.iloc[:, 26:]

# %%
df
# Out:
#               MONITOR_NAME  ADMIN_IM_YEAR ADMIN_IM_MONTH1 STATE_NAME  \
# 0              Aftab  Alam           2023         January  Jharkhand
# 1              Aftab  Alam           2023           March  Jharkhand
# 2              Aftab  Alam           2023             May  Jharkhand
# 3              Aftab  Alam           2023            June  Jharkhand
# 4              Aftab  Alam           2023         October  Jharkhand
# ..                     ...            ...             ...        ...
# 200  Yogendra Kumar Pandit           2023          August  Jharkhand
# 201  Yogendra Kumar Pandit           2023          August  Jharkhand
# 202  Yogendra Kumar Pandit           2023       September  Jharkhand
# 203  Yogendra Kumar Pandit           2023         October  Jharkhand
# 204  Yogendra Kumar Pandit           2023        December  Jharkhand
#
#     DISTRICT_NAME  COMP_S  COMP_SRI  COMP_U  C_GRADE_COUNT_T  ONGOING_S  ...  \
# ...

# %%
df = df.iloc[:, :-34]

# %%
df
# Out:
#               MONITOR_NAME  ADMIN_IM_YEAR ADMIN_IM_MONTH1 STATE_NAME  \
# 0              Aftab  Alam           2023         January  Jharkhand
# 1              Aftab  Alam           2023           March  Jharkhand
# 2              Aftab  Alam           2023             May  Jharkhand
# 3              Aftab  Alam           2023            June  Jharkhand
# 4              Aftab  Alam           2023         October  Jharkhand
# ..                     ...            ...             ...        ...
# 200  Yogendra Kumar Pandit           2023          August  Jharkhand
# 201  Yogendra Kumar Pandit           2023          August  Jharkhand
# 202  Yogendra Kumar Pandit           2023       September  Jharkhand
# 203  Yogendra Kumar Pandit           2023         October  Jharkhand
# 204  Yogendra Kumar Pandit           2023        December  Jharkhand
#
#     DISTRICT_NAME  COMP_S  COMP_SRI  COMP_U  C_GRADE_COUNT_T  ONGOING_S  ...  \
# ...

# %%
df.to_csv(path, index=False)
