# %%
import pandas as pd 
import numpy as np

# %%
path = 'nqm_monitor.csv'

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#      Textbox38        Textbox51      Textbox55 Textbox180 Textbox175 Textbox6  \
# 0      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 2      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 3      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 4      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# ...        ...              ...            ...        ...        ...      ...
# 1069   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1070   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1071   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1072   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1073   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
#
# ...

# %%
print(df)
# Out:
#      Textbox38        Textbox51      Textbox55 Textbox180 Textbox175 Textbox6  \
# 0      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 2      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 3      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 4      Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# ...        ...              ...            ...        ...        ...      ...
# 1069   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1070   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1071   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1072   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
# 1073   Grading  Completed Works  Ongoing Works     Sr.No.    Monitor     Year
#
# ...
